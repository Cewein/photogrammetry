# %% [markdown]
# ## importing lib

# %%
import numpy as np
import cv2
from scipy.ndimage import gaussian_filter

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ### function

# %%
def openAndRescale(path, rs=-1):
    basewidth = rs
    rgb = Image.open(path).convert('RGB')
    if(rs != -1):
        wpercent = (basewidth/float(rgb.size[0]))
        hsize = int((float(rgb.size[1])*float(wpercent)))
        rgb = rgb.resize((basewidth,hsize), Image.ANTIALIAS)
    rgb = np.array(rgb).astype(int)
    return rgb

#use real converstion value to keep rgb convetion to gray look
def rgbTogray(rgb_img):
    return np.dot(rgb_img[::],[0.2989, 0.5870, 0.1140]).astype(int)

def FAST(gray,epsilon,n):
    poi = np.zeros((gray.shape))
    
    #circle need to perform POI detection
    circle = np.array([[0,3],
            [-1,3],
            [-2,2],
            [-3,1],
            [-3,0],
            [-3,-1],
            [-2,-2],
            [-1,-3],
            [0,-3],
            [1,-3],
            [-2,2],
            [-1,3],
            [0,3],
            [1,3],
            [2,2],
            [1,3]
           ])
    
    #this can be parallelize on a gpu easly
    for x in range(3,gray.shape[0]-3):
        for y in range(3,gray.shape[1]-3):
            poiVal = 0
            
            #fast bail out if nothing found
            for i in range(0,16,4):
                if np.abs(gray[x + circle[i,0]][y + circle[i,1]] - gray[x][y]) >= epsilon:
                    poiVal += 1
            if poiVal < 3:
                continue
            
            #reset counter and add total for NMS
            poiVal = 0
            total = 0
            
            #check in a cirlce of raduis 3 around the pixel
            for i in range(16):
                if np.abs(gray[x + circle[i,0]][y + circle[i,1]] - gray[x][y]) >= epsilon:
                    total += np.abs(gray[x + circle[i,0]][y + circle[i,1]] - gray[x][y])
                    poiVal += 1
                else:
                    if poiVal >= n:
                        break
                    poiVal = 0
                    total = 0
                    
            
            if poiVal >= n:
                poi[x][y] = total
    return poi

# %%
def poiFromImage(path,rescale=-1,sigma=0,espilon=5,n=12,nonMaximaSupr=True,espNMS=2.25):
    
    #open rescale and pass to gray scale
    rgb = openAndRescale(path,rescale)
    gray = rgbTogray(rgb)
    
    #add gaussian if needed
    graygs = gaussian_filter(gray, sigma=sigma)

    #perform Features from Accelerated Segment Test
    poi = FAST(graygs,espilon,n)
    
    cleanPOI = None
    
    #remove maxima or not
    if nonMaximaSupr:
        cleanPOI = np.array(nonMaximaSupression(poi,espNMS))
    else:
        cleanPOI = np.array(np.nonzero(poi)).T
    
    return cleanPOI

# %%
def nonMaximaSupression(poi,eps):
    
    cleanPOI = []
    
    notZero = np.array(np.nonzero(poi)).T
    poi = poi[poi != 0]
    
    while(notZero.size != 0):
        
        #get max value
        value = np.argmax(poi)
        position = notZero[value]
        
        
        #remove it and add it to clean POI array
        notZero = np.delete(notZero,value,axis=0)
        poi = np.delete(poi,value,axis=0)
        cleanPOI.append(position)
            
        #compute distance to other POI
        dist = np.linalg.norm(notZero - position,axis=1)
        
        #remove those who are too close
        toDel = np.argwhere(dist < eps)
        notZero = np.delete(notZero,toDel,axis=0)
        poi = np.delete(poi,toDel,axis=0)
        
    return cleanPOI

# %% [markdown]
# ### demo

# %%
poi = poiFromImage("img/house2.png",espilon=10)
poiNone = poiFromImage("img/house2.png",espilon=10,nonMaximaSupr=False)

plt.figure()
plt.figure(figsize=(500//80, 500//80))
plt.scatter(cleanPOI[:,1],cleanPOI[:,0],s=10,c="#ff0000")
plt.imshow(rgb,cmap="gray")
plt.show()

# %%
image1 = cv2.imread("img/house2.png")

# Convert  image to RGB
image = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

# Convert image to gray scale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

fast = cv2.FastFeatureDetector_create() 

# Detect keypoints with non max suppression
keypoints_with_nonmax = fast.detect(gray, None)

# Disable nonmaxSuppression 
fast.setNonmaxSuppression(False)

# Detect keypoints without non max suppression
keypoints_without_nonmax = fast.detect(gray, None)

image_with_nonmax = np.copy(image)
image_without_nonmax = np.copy(image)

# Draw keypoints on top of the input image
cv2.drawKeypoints(image, keypoints_with_nonmax, image_with_nonmax, color=(0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2.drawKeypoints(image, keypoints_without_nonmax, image_without_nonmax, color=(0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Display image with and without non max suppression
fx, plots = plt.subplots(1, 2, figsize=(20,10))

plots[0].set_title("With non max suppression")
plots[0].imshow(image_with_nonmax)

plots[1].set_title("Without non max suppression")
plots[1].imshow(image_without_nonmax)
